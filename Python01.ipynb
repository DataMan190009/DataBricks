# %%
test

df = spark.table("workspace.default.emissions_data_2023")
##display(df)
df=df.groupBy("state_abbr").count().filter("count > 100")
display(df).orderBy("count",ascending=True)

# %%
df.show(n=2,vertical=False)

# %%
# %sql
select current_metastore()
